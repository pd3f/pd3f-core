# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import logging
import sys

# %%
# log everything
# logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)

# %%
logger = logging.getLogger('ddd')
logger.setLevel(logging.DEBUG)
logger.addHandler(logging.StreamHandler())

# %%
import ddd

# %%
output= ddd.run_parsr(
            '/Users/user/code/ddd/data/proc_pdf/analog_de/00109_05042016_Stellungnahme_bff_RefE_Stalking.pdf',
            cleaner_config=[],
            hostname_port="localhost:3001" 
        )
# Out:
# sending PDF to parsr
# > Polling server for the job 73b42d98109bad97e5697c6f7ce476...
# >> Progress percentage: 0
# >> Progress percentage: 0
# >> Progress percentage: 0
# >> Progress percentage: 0
# >> Progress percentage: 0
# >> Progress percentage: 0
# >> Progress percentage: 0
# >> Progress percentage: 0
# >> Job done!

# %%
e = ddd.Export(output)
# Out:
# media line width: 435.8
# media line width: 435.8
# median line height: 9.57
# median line height: 9.57
# median line space: 6.710000000000013
# median line space: 6.710000000000013
# counter width: [(435.87, 3), (436.37, 3), (436.28, 2), (436.49, 2), (436.32, 2)]
# counter width: [(435.87, 3), (436.37, 3), (436.28, 2), (436.49, 2), (436.32, 2)]
# counter height: [(9.15, 57), (9.57, 37), (9.99, 15), (10.4, 7), (8.74, 4)]
# counter height: [(9.15, 57), (9.57, 37), (9.99, 15), (10.4, 7), (8.74, 4)]
# counter lineheight: [(7.049999999999988, 13), (7.050000000000045, 5), (6.710000000000013, 4), (7.039999999999997, 4), (6.209999999999988, 4)]
# counter lineheight: [(7.049999999999988, 13), (7.050000000000045, 5), (6.710000000000013, 4), (7.039999999999997, 4), (6.209999999999988, 4)]
# is it a body para?
# is it a body para?
# yes!
# yes!
# is it a body para?
# is it a body para?
# is it a body para?
# is it a body para?
# yes!
# yes!
# exporting pages: 100%|██████████| 4/4 [00:00<00:00, 309.84it/s]
# No next line, but adding \n, avail space: 131.09100000000004 avg space: 2.358999999999996 ['Victims', 'of', 'Stalking.', 'American', 'Journal', 'of', 'Psychiatry', '2001;', '158:', '795-798']
# No next line, but adding \n, avail space: 131.09100000000004 avg space: 2.358999999999996 ['Victims', 'of', 'Stalking.', 'American', 'Journal', 'of', 'Psychiatry', '2001;', '158:', '795-798']
# adding newline here ['Victims', 'of', 'Stalking.', 'American', 'Journal', 'of', 'Psychiatry', '2001;', '158:', '795-798\n']
# adding newline here ['Victims', 'of', 'Stalking.', 'American', 'Journal', 'of', 'Psychiatry', '2001;', '158:', '795-798\n']
# exporting pages:   0%|          | 0/4 [00:00<?, ?it/s]adding newline here ['FRAUEN', 'GEGEN', 'GEWALT', 'E.¥.\n']
# adding newline here ['FRAUEN', 'GEGEN', 'GEWALT', 'E.¥.\n']
# No next line, but adding \n, avail space: 331.37500000000006 avg space: 1.9450000000000003 ['gegen', 'Nachstellungen']
# No next line, but adding \n, avail space: 331.37500000000006 avg space: 1.9450000000000003 ['gegen', 'Nachstellungen']
# adding newline here ['gegen', 'Nachstellungen\n']
# adding newline here ['gegen', 'Nachstellungen\n']
# No next line, but adding \n, avail space: 292.7733333333333 avg space: 2.326666666666673 ['Nachstellungen', 'zu', 'verbessern.']
# No next line, but adding \n, avail space: 292.7733333333333 avg space: 2.326666666666673 ['Nachstellungen', 'zu', 'verbessern.']
# adding newline here ['Nachstellungen', 'zu', 'verbessern.\n']
# adding newline here ['Nachstellungen', 'zu', 'verbessern.\n']
# adding newline here ['Zu', 'den', 'Änderungen', 'im', 'Einzelnen\n']
# adding newline here ['Zu', 'den', 'Änderungen', 'im', 'Einzelnen\n']
# There is enough space on the lext for the next word. So adding a linebreak between ['Artikel', '1:', 'Änderung', 'des', 'Strafgesetzbuches']['Der', 'bff', 'begrüßt', 'die', 'Umwandlung', 'des', '§', '238', 'Absatz', '1', 'von', 'einem', 'Erfoigs-', 'in', 'ein', 'Eignungsdelikt']
# There is enough space on the lext for the next word. So adding a linebreak between ['Artikel', '1:', 'Änderung', 'des', 'Strafgesetzbuches']['Der', 'bff', 'begrüßt', 'die', 'Umwandlung', 'des', '§', '238', 'Absatz', '1', 'von', 'einem', 'Erfoigs-', 'in', 'ein', 'Eignungsdelikt']
# adding newline here ['Artikel', '1:', 'Änderung', 'des', 'Strafgesetzbuches\n']
# adding newline here ['Artikel', '1:', 'Änderung', 'des', 'Strafgesetzbuches\n']
# No next line, but adding \n, avail space: 360.26 avg space: 0.0 ['außerordentlich.']
# No next line, but adding \n, avail space: 360.26 avg space: 0.0 ['außerordentlich.']
# adding newline here ['außerordentlich.\n']
# adding newline here ['außerordentlich.\n']
# No next line, but adding \n, avail space: 280.9766666666667 avg space: 2.4433333333333374 ['Strafverfolgung', 'quasi', 'verhindert.']
# No next line, but adding \n, avail space: 280.9766666666667 avg space: 2.4433333333333374 ['Strafverfolgung', 'quasi', 'verhindert.']
# adding newline here ['Strafverfolgung', 'quasi', 'verhindert.\n']
# adding newline here ['Strafverfolgung', 'quasi', 'verhindert.\n']
# No next line, but adding space ['aufzustellen', 'und', 'zumindest', 'in', 'der', 'Gesetzesbegründung', 'festzulegen.', 'Hierzu', 'sollten']
# No next line, but adding space ['aufzustellen', 'und', 'zumindest', 'in', 'der', 'Gesetzesbegründung', 'festzulegen.', 'Hierzu', 'sollten']
# last line, not adding space
# last line, not adding space
# No next line, but adding \n, avail space: 357.94 avg space: 2.289999999999997 ['Formen', 'von', 'Gewalt.']
# No next line, but adding \n, avail space: 357.94 avg space: 2.289999999999997 ['Formen', 'von', 'Gewalt.']
# adding newline here ['Formen', 'von', 'Gewalt.\n']
# adding newline here ['Formen', 'von', 'Gewalt.\n']
# exporting pages:  25%|██▌       | 1/4 [00:00<00:01,  2.38it/s]No next line, but adding \n, avail space: 199.61833333333334 avg space: 3.1516666666666615 ['herangezogen', 'und', 'ggf.', 'weitere', 'eingeholt', 'werden.']
# No next line, but adding \n, avail space: 199.61833333333334 avg space: 3.1516666666666615 ['herangezogen', 'und', 'ggf.', 'weitere', 'eingeholt', 'werden.']
# adding newline here ['herangezogen', 'und', 'ggf.', 'weitere', 'eingeholt', 'werden.\n']
# adding newline here ['herangezogen', 'und', 'ggf.', 'weitere', 'eingeholt', 'werden.\n']
# No next line, but adding \n, avail space: 133.482 avg space: 3.1579999999999986 ['Betroffenen', 'erhebliche', 'negative', 'Konsequenzen', 'herbeizuführen.']
# No next line, but adding \n, avail space: 133.482 avg space: 3.1579999999999986 ['Betroffenen', 'erhebliche', 'negative', 'Konsequenzen', 'herbeizuführen.']
# adding newline here ['Betroffenen', 'erhebliche', 'negative', 'Konsequenzen', 'herbeizuführen.\n']
# adding newline here ['Betroffenen', 'erhebliche', 'negative', 'Konsequenzen', 'herbeizuführen.\n']
# No next line, but adding \n, avail space: 186.17666666666668 avg space: 2.7933333333333317 ['sind', 'wie', 'die', 'Überlebenden', 'eines', 'Flugzeugabsturzes”.']
# No next line, but adding \n, avail space: 186.17666666666668 avg space: 2.7933333333333317 ['sind', 'wie', 'die', 'Überlebenden', 'eines', 'Flugzeugabsturzes”.']
# adding newline here ['sind', 'wie', 'die', 'Überlebenden', 'eines', 'Flugzeugabsturzes”.\n']
# adding newline here ['sind', 'wie', 'die', 'Überlebenden', 'eines', 'Flugzeugabsturzes”.\n']
# No next line, but adding \n, avail space: 79.64125000000003 avg space: 2.578750000000003 ['Geeignetheit', 'zur', 'Beeinträchtigung', 'der', 'Lebensgestaltung', 'auch', 'erkannt', 'wird.']
# No next line, but adding \n, avail space: 79.64125000000003 avg space: 2.578750000000003 ['Geeignetheit', 'zur', 'Beeinträchtigung', 'der', 'Lebensgestaltung', 'auch', 'erkannt', 'wird.']
# adding newline here ['Geeignetheit', 'zur', 'Beeinträchtigung', 'der', 'Lebensgestaltung', 'auch', 'erkannt', 'wird.\n']
# adding newline here ['Geeignetheit', 'zur', 'Beeinträchtigung', 'der', 'Lebensgestaltung', 'auch', 'erkannt', 'wird.\n']
# There is enough space on the lext for the next word. So adding a linebreak between ['Handlungen', 'von', 'den', 'Betroffenen', 'als', 'besonders', 'ängstigend', 'erlebt', 'werden.']['In', 'der', 'Praxis', 'kommen', 'durchaus', 'Tathandlungen', 'vor,', 'die', 'durch', 'Streichung', 'der', 'Generalklausel']
# There is enough space on the lext for the next word. So adding a linebreak between ['Handlungen', 'von', 'den', 'Betroffenen', 'als', 'besonders', 'ängstigend', 'erlebt', 'werden.']['In', 'der', 'Praxis', 'kommen', 'durchaus', 'Tathandlungen', 'vor,', 'die', 'durch', 'Streichung', 'der', 'Generalklausel']
# adding newline here ['Handlungen', 'von', 'den', 'Betroffenen', 'als', 'besonders', 'ängstigend', 'erlebt', 'werden.\n']
# adding newline here ['Handlungen', 'von', 'den', 'Betroffenen', 'als', 'besonders', 'ängstigend', 'erlebt', 'werden.\n']
# No next line, but adding \n, avail space: 168.20666666666665 avg space: 2.893333333333331 ['Möglichkeiten', 'der', 'Nachstellung', 'stetig', 'weiter', 'entwickeln.']
# No next line, but adding \n, avail space: 168.20666666666665 avg space: 2.893333333333331 ['Möglichkeiten', 'der', 'Nachstellung', 'stetig', 'weiter', 'entwickeln.']
# adding newline here ['Möglichkeiten', 'der', 'Nachstellung', 'stetig', 'weiter', 'entwickeln.\n']
# adding newline here ['Möglichkeiten', 'der', 'Nachstellung', 'stetig', 'weiter', 'entwickeln.\n']
# exporting pages:  50%|█████     | 2/4 [00:00<00:00,  2.62it/s]There is enough space on the lext for the next word. So adding a linebreak between ['erfasst', 'werden,', 'strafbar', 'sind.']['Die', 'im', 'Gesetzentwurf', 'beschriebene', 'Sorge', 'der', 'zu', 'weit', 'gehenden', 'Strafbarkeit', 'teilt', 'der', 'bff']
# There is enough space on the lext for the next word. So adding a linebreak between ['erfasst', 'werden,', 'strafbar', 'sind.']['Die', 'im', 'Gesetzentwurf', 'beschriebene', 'Sorge', 'der', 'zu', 'weit', 'gehenden', 'Strafbarkeit', 'teilt', 'der', 'bff']
# adding newline here ['erfasst', 'werden,', 'strafbar', 'sind.\n']
# adding newline here ['erfasst', 'werden,', 'strafbar', 'sind.\n']
# No next line, but adding \n, avail space: 262.474 avg space: 2.9160000000000026 ['Dies', 'ist', 'als', 'Eingrenzung', 'ausreichend.']
# No next line, but adding \n, avail space: 262.474 avg space: 2.9160000000000026 ['Dies', 'ist', 'als', 'Eingrenzung', 'ausreichend.']
# adding newline here ['Dies', 'ist', 'als', 'Eingrenzung', 'ausreichend.\n']
# adding newline here ['Dies', 'ist', 'als', 'Eingrenzung', 'ausreichend.\n']
# There is enough space on the lext for the next word. So adding a linebreak between ['Artikel', '2:', 'Änderung', 'der', 'Strafprozessordnung']['Die', 'Streichung', 'von', '§', '238', 'Absatz', '1', 'StGB', 'aus', 'dem', 'Katalog', 'der', 'Privatklagedelikte', 'ist']
# There is enough space on the lext for the next word. So adding a linebreak between ['Artikel', '2:', 'Änderung', 'der', 'Strafprozessordnung']['Die', 'Streichung', 'von', '§', '238', 'Absatz', '1', 'StGB', 'aus', 'dem', 'Katalog', 'der', 'Privatklagedelikte', 'ist']
# adding newline here ['Artikel', '2:', 'Änderung', 'der', 'Strafprozessordnung\n']
# adding newline here ['Artikel', '2:', 'Änderung', 'der', 'Strafprozessordnung\n']
# No next line, but adding \n, avail space: 292.6066666666667 avg space: 2.463333333333329 ['uneingeschränkt', 'zu', 'begrüßen.']
# No next line, but adding \n, avail space: 292.6066666666667 avg space: 2.463333333333329 ['uneingeschränkt', 'zu', 'begrüßen.']
# adding newline here ['uneingeschränkt', 'zu', 'begrüßen.\n']
# adding newline here ['uneingeschränkt', 'zu', 'begrüßen.\n']
# There is enough space on the lext for the next word. So adding a linebreak between ['Artikel', '3', 'und', '4:', 'Ausdehnung', 'des', 'Tatbestandes', 'des', '§', '4', 'GewSchG']['In', 'der', 'Praxis', 'zeigt', 'sich', 'häufig', 'das', 'Problem', 'Abschlusses', 'von', 'bislang', 'nicht', 'strafbewehrten']
# There is enough space on the lext for the next word. So adding a linebreak between ['Artikel', '3', 'und', '4:', 'Ausdehnung', 'des', 'Tatbestandes', 'des', '§', '4', 'GewSchG']['In', 'der', 'Praxis', 'zeigt', 'sich', 'häufig', 'das', 'Problem', 'Abschlusses', 'von', 'bislang', 'nicht', 'strafbewehrten']
# adding newline here ['Artikel', '3', 'und', '4:', 'Ausdehnung', 'des', 'Tatbestandes', 'des', '§', '4', 'GewSchG\n']
# adding newline here ['Artikel', '3', 'und', '4:', 'Ausdehnung', 'des', 'Tatbestandes', 'des', '§', '4', 'GewSchG\n']
# There is enough space on the lext for the next word. So adding a linebreak between ['Vergleichen.']['Fachberatungsstellen', 'haben', 'nicht', 'selten', 'mit', 'Fällen', 'zu', 'tun,', 'in', 'denen', 'die', 'Betroffenen', 'davon']
# There is enough space on the lext for the next word. So adding a linebreak between ['Vergleichen.']['Fachberatungsstellen', 'haben', 'nicht', 'selten', 'mit', 'Fällen', 'zu', 'tun,', 'in', 'denen', 'die', 'Betroffenen', 'davon']
# adding newline here ['Vergleichen.\n']
# adding newline here ['Vergleichen.\n']
# There is enough space on the lext for the next word. So adding a linebreak between ['erschüttert,', 'wenn', 'ihnen', 'bewusst', 'wird,', 'dass', 'damit', 'der', 'strafrechtliche', 'Schutz', 'entfällt.']['Wir', 'kennen', 'aus', 'der', 'Praxis', 'den', 'großen', 'Erledigungsdruck', 'der', 'Gerichte,', 'für', 'die', 'der', 'Abschluss']
# There is enough space on the lext for the next word. So adding a linebreak between ['erschüttert,', 'wenn', 'ihnen', 'bewusst', 'wird,', 'dass', 'damit', 'der', 'strafrechtliche', 'Schutz', 'entfällt.']['Wir', 'kennen', 'aus', 'der', 'Praxis', 'den', 'großen', 'Erledigungsdruck', 'der', 'Gerichte,', 'für', 'die', 'der', 'Abschluss']
# adding newline here ['erschüttert,', 'wenn', 'ihnen', 'bewusst', 'wird,', 'dass', 'damit', 'der', 'strafrechtliche', 'Schutz', 'entfällt.\n']
# adding newline here ['erschüttert,', 'wenn', 'ihnen', 'bewusst', 'wird,', 'dass', 'damit', 'der', 'strafrechtliche', 'Schutz', 'entfällt.\n']
# There is enough space on the lext for the next word. So adding a linebreak between ['Vergleich', 'in', '$', '4', 'Abs.', 'Nr.', '2', 'GewaltschG', 'aufgenommen', 'wird.', 'Insoweit', 'sollte', 'aber', 'nicht', 'die', ',']['n', 'i']
# There is enough space on the lext for the next word. So adding a linebreak between ['Vergleich', 'in', '$', '4', 'Abs.', 'Nr.', '2', 'GewaltschG', 'aufgenommen', 'wird.', 'Insoweit', 'sollte', 'aber', 'nicht', 'die', ',']['n', 'i']
# adding newline here ['Vergleich', 'in', '$', '4', 'Abs.', 'Nr.', '2', 'GewaltschG', 'aufgenommen', 'wird.', 'Insoweit', 'sollte', 'aber', 'nicht', 'die', ',\n']
# adding newline here ['Vergleich', 'in', '$', '4', 'Abs.', 'Nr.', '2', 'GewaltschG', 'aufgenommen', 'wird.', 'Insoweit', 'sollte', 'aber', 'nicht', 'die', ',\n']
# testing the lines:
# testing the lines:
# ['n', 'i'] ['gerichtliche', 'Bestätigung,', 'wie', 'im', '§', '214a', 'FamFG', 'vorgesehen,', 'Voraussetzung', 'sein.', 'Hierdurch', '|.']
# ['n', 'i'] ['gerichtliche', 'Bestätigung,', 'wie', 'im', '§', '214a', 'FamFG', 'vorgesehen,', 'Voraussetzung', 'sein.', 'Hierdurch', '|.']
# adding newline here ['n', 'i\n']
# adding newline here ['n', 'i\n']
# No next line, but adding \n, avail space: 3.5129999999999946 avg space: 2.5170000000000075 ['prüfungspflicht,', 'ggf.', 'mit', 'Beweisaufnahme', 'durch', 'das', 'Gericht,', 'erforderlich.', 'Den', '‚Gerichten']
# No next line, but adding \n, avail space: 3.5129999999999946 avg space: 2.5170000000000075 ['prüfungspflicht,', 'ggf.', 'mit', 'Beweisaufnahme', 'durch', 'das', 'Gericht,', 'erforderlich.', 'Den', '‚Gerichten']
# adding newline here ['prüfungspflicht,', 'ggf.', 'mit', 'Beweisaufnahme', 'durch', 'das', 'Gericht,', 'erforderlich.', 'Den', '‚Gerichten\n']
# adding newline here ['prüfungspflicht,', 'ggf.', 'mit', 'Beweisaufnahme', 'durch', 'das', 'Gericht,', 'erforderlich.', 'Den', '‚Gerichten\n']
# There is enough space on the lext for the next word. So adding a linebreak between ['gleich.']['Sinn', 'und']
# There is enough space on the lext for the next word. So adding a linebreak between ['gleich.']['Sinn', 'und']
# adding newline here ['gleich.\n']
# adding newline here ['gleich.\n']
# There is enough space on the lext for the next word. So adding a linebreak between ['Sinn', 'und']['Zweck', 'des', 'Vergleichs', 'ist', 'es', 'aber', 'gerade', 'nicht', 'zuletzt', 'auch,', '‘ohne', 'vollständige']
# There is enough space on the lext for the next word. So adding a linebreak between ['Sinn', 'und']['Zweck', 'des', 'Vergleichs', 'ist', 'es', 'aber', 'gerade', 'nicht', 'zuletzt', 'auch,', '‘ohne', 'vollständige']
# adding newline here ['Sinn', 'und\n']
# adding newline here ['Sinn', 'und\n']
# There is enough space on the lext for the next word. So adding a linebreak between ['Ausermittlung', 'des', 'Falles', 'eine', 'gütliche', 'Regelung', 'zwischen', 'den', 'Parteien', 'zu', 'finden.']['Es', 'stellt', 'auch', 'keine', 'unzulässige', 'Strafbarkeitsausdehnung', 'dar,', 'wenn', 'nicht', 'erst', 'ein', 'Gericht']
# There is enough space on the lext for the next word. So adding a linebreak between ['Ausermittlung', 'des', 'Falles', 'eine', 'gütliche', 'Regelung', 'zwischen', 'den', 'Parteien', 'zu', 'finden.']['Es', 'stellt', 'auch', 'keine', 'unzulässige', 'Strafbarkeitsausdehnung', 'dar,', 'wenn', 'nicht', 'erst', 'ein', 'Gericht']
# adding newline here ['Ausermittlung', 'des', 'Falles', 'eine', 'gütliche', 'Regelung', 'zwischen', 'den', 'Parteien', 'zu', 'finden.\n']
# adding newline here ['Ausermittlung', 'des', 'Falles', 'eine', 'gütliche', 'Regelung', 'zwischen', 'den', 'Parteien', 'zu', 'finden.\n']
# There is enough space on the lext for the next word. So adding a linebreak between ['oder', 'nicht.']['Insofern', 'halten', 'wir', 'eine', 'Regelung', 'für', 'sinnvoll,', 'die', 'einen', 'qualifizierten', 'Vergleich', 'für', 'die', 'Fälle']
# There is enough space on the lext for the next word. So adding a linebreak between ['oder', 'nicht.']['Insofern', 'halten', 'wir', 'eine', 'Regelung', 'für', 'sinnvoll,', 'die', 'einen', 'qualifizierten', 'Vergleich', 'für', 'die', 'Fälle']
# adding newline here ['oder', 'nicht.\n']
# adding newline here ['oder', 'nicht.\n']
# No next line, but adding space ['Vergleich', 'zu', 'begründen.', 'Es', 'sollte', 'außerdem', 'als', 'notwendiger', 'Teil', 'des', 'Vergleichs']
# No next line, but adding space ['Vergleich', 'zu', 'begründen.', 'Es', 'sollte', 'außerdem', 'als', 'notwendiger', 'Teil', 'des', 'Vergleichs']
# last line, not adding space
# last line, not adding space
# exporting pages:  75%|███████▌  | 3/4 [00:04<00:01,  1.33s/it]No next line, but adding \n, avail space: 103.07799999999999 avg space: 3.4319999999999977 ['gegen', 'den', 'Vergleich', 'eine', 'Strafbarkeit', 'nach', '8', '4', 'GewaitschG', 'begründet.']
# No next line, but adding \n, avail space: 103.07799999999999 avg space: 3.4319999999999977 ['gegen', 'den', 'Vergleich', 'eine', 'Strafbarkeit', 'nach', '8', '4', 'GewaitschG', 'begründet.']
# adding newline here ['gegen', 'den', 'Vergleich', 'eine', 'Strafbarkeit', 'nach', '8', '4', 'GewaitschG', 'begründet.\n']
# adding newline here ['gegen', 'den', 'Vergleich', 'eine', 'Strafbarkeit', 'nach', '8', '4', 'GewaitschG', 'begründet.\n']
# There is enough space on the lext for the next word. So adding a linebreak between ['Weitere', 'Anmerkungen', 'zum', 'Gesetzentwurf']['Die', 'Intention', 'des', 'Gesetzentwurfs,', 'einen', 'besseren', 'Opferschutz', 'in', 'Fällen', 'von', 'Nachstellungen']
# There is enough space on the lext for the next word. So adding a linebreak between ['Weitere', 'Anmerkungen', 'zum', 'Gesetzentwurf']['Die', 'Intention', 'des', 'Gesetzentwurfs,', 'einen', 'besseren', 'Opferschutz', 'in', 'Fällen', 'von', 'Nachstellungen']
# adding newline here ['Weitere', 'Anmerkungen', 'zum', 'Gesetzentwurf\n']
# adding newline here ['Weitere', 'Anmerkungen', 'zum', 'Gesetzentwurf\n']
# No next line, but adding \n, avail space: 363.20500000000004 avg space: 2.2650000000000077 ['werden', 'sollten:']
# No next line, but adding \n, avail space: 363.20500000000004 avg space: 2.2650000000000077 ['werden', 'sollten:']
# adding newline here ['werden', 'sollten:\n']
# adding newline here ['werden', 'sollten:\n']
# No next line, but adding \n, avail space: 342.29999999999995 avg space: 2.049999999999997 ['geschaffen', 'wird.']
# No next line, but adding \n, avail space: 342.29999999999995 avg space: 2.049999999999997 ['geschaffen', 'wird.']
# adding newline here ['geschaffen', 'wird.\n']
# adding newline here ['geschaffen', 'wird.\n']
# No next line, but adding \n, avail space: 351.64000000000004 avg space: 0.0 ['Opferschutzes.']
# No next line, but adding \n, avail space: 351.64000000000004 avg space: 0.0 ['Opferschutzes.']
# adding newline here ['Opferschutzes.\n']
# adding newline here ['Opferschutzes.\n']
# No next line, but adding \n, avail space: 91.72999999999996 avg space: 3.44 ['dass', 'der', 'Gewaltschutz', 'durch', 'Umgangsregelungen', 'konterkariert', 'wird.']
# No next line, but adding \n, avail space: 91.72999999999996 avg space: 3.44 ['dass', 'der', 'Gewaltschutz', 'durch', 'Umgangsregelungen', 'konterkariert', 'wird.']
# adding newline here ['dass', 'der', 'Gewaltschutz', 'durch', 'Umgangsregelungen', 'konterkariert', 'wird.\n']
# adding newline here ['dass', 'der', 'Gewaltschutz', 'durch', 'Umgangsregelungen', 'konterkariert', 'wird.\n']
# adding newline here ['Berlin,', '04.05.2016\n']
# adding newline here ['Berlin,', '04.05.2016\n']
# testing the lines:
# testing the lines:
# ['bff:', 'Bundesverband', 'Frauenberatungsstellen', 'und', 'Frauennotrufe'] ['www', '.frauen-gegen-gewalt.de']
# ['bff:', 'Bundesverband', 'Frauenberatungsstellen', 'und', 'Frauennotrufe'] ['www', '.frauen-gegen-gewalt.de']
# adding newline here ['bff:', 'Bundesverband', 'Frauenberatungsstellen', 'und', 'Frauennotrufe\n']
# adding newline here ['bff:', 'Bundesverband', 'Frauenberatungsstellen', 'und', 'Frauennotrufe\n']
# No next line, but adding \n, avail space: 157.7 avg space: -0.21999999999999886 ['www', '.frauen-gegen-gewalt.de']
# No next line, but adding \n, avail space: 157.7 avg space: -0.21999999999999886 ['www', '.frauen-gegen-gewalt.de']
# adding newline here ['www', '.frauen-gegen-gewalt.de\n']
# adding newline here ['www', '.frauen-gegen-gewalt.de\n']
# exporting pages: 100%|██████████| 4/4 [00:08<00:00,  2.14s/it]
# trying to reverse page breaks: 0it [00:00, ?it/s]the last element has ends with a newline. Do not try to join with the next one.
# the last element has ends with a newline. Do not try to join with the next one.
# the last element has ends with a newline. Do not try to join with the next one.
# the last element has ends with a newline. Do not try to join with the next one.
# trying to reverse page breaks: 2it [00:00, 18.11it/s]joining the following paragraphs
# joining the following paragraphs
# gleich.
# Sinn und
# Zweck des Vergleichs ist es aber gerade nicht zuletzt auch, ‘ohne vollständige Ausermittlung des Falles eine gütliche Regelung zwischen den Parteien zu finden.
# Es stellt auch keine unzulässige Strafbarkeitsausdehnung dar, wenn nicht erst ein Gericht den Vergleich genehmigt, denn jeder Partei ist es unbenommen, einen Vergleich einzugehen oder nicht.
# Insofern halten wir eine Regelung für sinnvoll, die einen qualifizierten Vergleich für die Fälle des $ 4 GewaltSchG vorsieht. Es sollte eine gerichtliche Belehrungspflicht hinsichtlich der Strafbarkeit eines Verstoßes gegen den Vergleich erforderlich sein, die ausdrücklich im gerichtlichen Protokoll aufzunehmen ist, um die Strafbarkeit des Verstoßes gegen den Vergleich zu begründen. Es sollte außerdem als notwendiger Teil des Vergleichs Weitere Anmerkungen zum Gesetzentwurf
# Die Intention des Gesetzentwurfs, einen besseren Opferschutz in Fällen von Nachstellungen zu erreichen, ist uneingeschränkt zu begrüßen. In der Praxis der Unterstützung von Stalking-Betroffenen zeigen sich gemäß den Erfahrungen der Fachberatungsstellen weitere Schwierigkeiten, die mit dem Ziel der Verbesserung des Opferschutzes dringend bearbeitet werden sollten:
#
#
#
# Weitere Anmerkungen zum Gesetzentwurf
# Die Intention des Gesetzentwurfs, einen besseren Opferschutz in Fällen von Nachstellungen zu erreichen, ist uneingeschränkt zu begrüßen. In der Praxis der Unterstützung von Stalking-Betroffenen zeigen sich gemäß den Erfahrungen der Fachberatungsstellen weitere Schwierigkeiten, die mit dem Ziel der Verbesserung des Opferschutzes dringend bearbeitet werden sollten:
#
#
#
# gleich.
# Sinn und
# Zweck des Vergleichs ist es aber gerade nicht zuletzt auch, ‘ohne vollständige Ausermittlung des Falles eine gütliche Regelung zwischen den Parteien zu finden.
# Es stellt auch keine unzulässige Strafbarkeitsausdehnung dar, wenn nicht erst ein Gericht den Vergleich genehmigt, denn jeder Partei ist es unbenommen, einen Vergleich einzugehen oder nicht.
# Insofern halten wir eine Regelung für sinnvoll, die einen qualifizierten Vergleich für die Fälle des $ 4 GewaltSchG vorsieht. Es sollte eine gerichtliche Belehrungspflicht hinsichtlich der Strafbarkeit eines Verstoßes gegen den Vergleich erforderlich sein, die ausdrücklich im gerichtlichen Protokoll aufzunehmen ist, um die Strafbarkeit des Verstoßes gegen den Vergleich zu begründen. Es sollte außerdem als notwendiger Teil des Vergleichs Weitere Anmerkungen zum Gesetzentwurf
# Die Intention des Gesetzentwurfs, einen besseren Opferschutz in Fällen von Nachstellungen zu erreichen, ist uneingeschränkt zu begrüßen. In der Praxis der Unterstützung von Stalking-Betroffenen zeigen sich gemäß den Erfahrungen der Fachberatungsstellen weitere Schwierigkeiten, die mit dem Ziel der Verbesserung des Opferschutzes dringend bearbeitet werden sollten:
#
#
#
# gleich.
# Sinn und
# Zweck des Vergleichs ist es aber gerade nicht zuletzt auch, ‘ohne vollständige Ausermittlung des Falles eine gütliche Regelung zwischen den Parteien zu finden.
# Es stellt auch keine unzulässige Strafbarkeitsausdehnung dar, wenn nicht erst ein Gericht den Vergleich genehmigt, denn jeder Partei ist es unbenommen, einen Vergleich einzugehen oder nicht.
# Insofern halten wir eine Regelung für sinnvoll, die einen qualifizierten Vergleich für die Fälle des $ 4 GewaltSchG vorsieht. Es sollte eine gerichtliche Belehrungspflicht hinsichtlich der Strafbarkeit eines Verstoßes gegen den Vergleich erforderlich sein, die ausdrücklich im gerichtlichen Protokoll aufzunehmen ist, um die Strafbarkeit des Verstoßes gegen den Vergleich zu begründen. Es sollte außerdem als notwendiger Teil des Vergleichs Weitere Anmerkungen zum Gesetzentwurf
# Die Intention des Gesetzentwurfs, einen besseren Opferschutz in Fällen von Nachstellungen zu erreichen, ist uneingeschränkt zu begrüßen. In der Praxis der Unterstützung von Stalking-Betroffenen zeigen sich gemäß den Erfahrungen der Fachberatungsstellen weitere Schwierigkeiten, die mit dem Ziel der Verbesserung des Opferschutzes dringend bearbeitet werden sollten:
#
#
#
# Weitere Anmerkungen zum Gesetzentwurf
# Die Intention des Gesetzentwurfs, einen besseren Opferschutz in Fällen von Nachstellungen zu erreichen, ist uneingeschränkt zu begrüßen. In der Praxis der Unterstützung von Stalking-Betroffenen zeigen sich gemäß den Erfahrungen der Fachberatungsstellen weitere Schwierigkeiten, die mit dem Ziel der Verbesserung des Opferschutzes dringend bearbeitet werden sollten:
#
#
#
# gleich.
# Sinn und
# Zweck des Vergleichs ist es aber gerade nicht zuletzt auch, ‘ohne vollständige Ausermittlung des Falles eine gütliche Regelung zwischen den Parteien zu finden.
# Es stellt auch keine unzulässige Strafbarkeitsausdehnung dar, wenn nicht erst ein Gericht den Vergleich genehmigt, denn jeder Partei ist es unbenommen, einen Vergleich einzugehen oder nicht.
# Insofern halten wir eine Regelung für sinnvoll, die einen qualifizierten Vergleich für die Fälle des $ 4 GewaltSchG vorsieht. Es sollte eine gerichtliche Belehrungspflicht hinsichtlich der Strafbarkeit eines Verstoßes gegen den Vergleich erforderlich sein, die ausdrücklich im gerichtlichen Protokoll aufzunehmen ist, um die Strafbarkeit des Verstoßes gegen den Vergleich zu begründen. Es sollte außerdem als notwendiger Teil des Vergleichs Weitere Anmerkungen zum Gesetzentwurf
# Die Intention des Gesetzentwurfs, einen besseren Opferschutz in Fällen von Nachstellungen zu erreichen, ist uneingeschränkt zu begrüßen. In der Praxis der Unterstützung von Stalking-Betroffenen zeigen sich gemäß den Erfahrungen der Fachberatungsstellen weitere Schwierigkeiten, die mit dem Ziel der Verbesserung des Opferschutzes dringend bearbeitet werden sollten:
#
#
#
# trying to reverse page breaks: 3it [00:03,  1.01s/it]

# %%
print(e.text())
# Out:
# FRAUEN GEGEN GEWALT E.¥.
#
# Stellungnahme des bff: Bundesverband Frauenberatungsstellen und Frauennotrufe — Frauen gegen Gewalt e.V. zum Entwurf eines Gesetzes zur Verbesserung des Schutzes gegen Nachstellungen
#
# Der bff: Bundesverband Frauenberatungsstellen und Frauennotrufe bedankt sich für die Möglichkeit, Stellung zum vorgelegten Entwurf beziehen zu können. Der bff begrüßt das Vorhaben des Bundesministeriums der Justiz und für Verbraucherschutz, den Schutz vor Nachstellungen zu verbessern.
#
# Zu den Änderungen im Einzelnen
#
# Artikel 1: Änderung des Strafgesetzbuches
# Der bff begrüßt die Umwandlung des § 238 Absatz 1 von einem Erfoigs- in ein Eignungsdelikt außerordentlich.
#
# Bislang hing die Strafbarkeit von Nachstellungen ganz entscheidend davon ab, wie den Betroffenen der Umgang mit der Situation gelang. Betroffene, die aufgrund eines stabilen sozialen Umfeldes oder anderer positiver Einflussfaktoren (noch) nicht dazu gezwungen waren, ihre Lebensführung aufgrund der Nachstellungen massiv zu verändern, waren bislang im Nachteil. Dadurch wurde auch häufig das Ziel der Unterstützung der Betroffenen konterkariert. In der Beratung geht es darum, gemeinsam mit den Betroffenen einen Umgang mit den Nachstellungen zu erarbeiten, der eine größtmögliche Stabilität in der Lebensführung ermöglicht. Gelang dies gut, wurde damit gleichzeitig die Möglichkeit der Strafverfolgung quasi verhindert.
#
# Insofern ist es erforderlich, dass das Delikt als Eignungsdelikt ausgestaltet wird. Gleichzeitig bleibt jedoch die Frage, wie die Rechtsprechung die Frage der objektiven Geeignetheit ausgestalten wird, sodass dringend versucht werden sollte, Kriterien dahingehend aufzustellen und zumindest in der Gesetzesbegründung festzulegen. Hierzu sollten
#
# * Der bff: Bundesverband Frauenberatungsstellen und Frauennotrufe ist der Dachverband von bundesweit uber 170 spezialisierten Fachberatungsstelien für gewaltbetroffene Frauen und Madchen. Die dem bff angeschlossenen Frauenberatungsstellen und Frauennotrufe beraten und unterstützen zu ganz verschiedenen Formen von Gewalt.
#
# wissenschaftliche Erkenntnisse zu den Folgen von Nachstellungshandlungen ausdrücklich herangezogen und ggf. weitere eingeholt werden.
#
# Die Frauenberatungsstellen und Frauennotrufe können auf langjährige Praxis der Beratung und Unterstützung von Betroffenen verweisen. Dabei wird immer wieder deutlich, dass schon niedrigschwellige, aber sehr häufige Stalkinghandlungen geeignet sind, für die Betroffenen erhebliche negative Konsequenzen herbeizuführen.
#
# Die Folgen von Stalking sind vielfältiger Natur und können für Betroffene gravierend sein. Sie reichen von psychischen Folgen wie Angstzuständen und Schlafstörungen, bis hin zu schweren Depressionen und Suizidgedanken, hinzu kommen oft auch körperliche Folgen durch den dauerhaften Stress, wie z.B. Magenbeschwerden, ein gestörtes Immunsystem und vieles mehr. Aufgrund von Panik das Haus zu verlassen und notwendigen Schutzmaßnahmen wie Rufnummernwechsel, Verzicht auf soziale Netzwerke oder Umzug verlieren viele Betroffene außerdem ihr wichtiges soziales Umfeld. Viele dieser Beschwerden und Probleme halten auch Jahre nach Ende des Stalkings noch an, einige vergehen nie. Durch die Forschung ist belegt, dass Stalking-Betroffene demselben psychischen und physischen Stress ausgesetzt sind wie die Überlebenden eines Flugzeugabsturzes”.
#
# Es ist außerordentlich zu begrüßen, dass aufgrund der Umwandlung in ein Eignungsdelikt künftig die schlimmsten Folgen nicht erst eingetreten sein müssen, damit die Nachstellungen strafrechtlich relevant sind. Dies kann dazu beitragen, dass im Falle frühzeitiger Strafanzeigen durch die strafrechtliche Sanktionierung langandauernde Stalking-Verläufe vermieden werden können. Umso wichtiger ist es aber, dass den Ermittlungsbehörden und Gerichten die potenziell lebensverändernden Folgen ausreichend bewusst sind, damit die Geeignetheit zur Beeinträchtigung der Lebensgestaltung auch erkannt wird.
#
# Die im Gegenzug geplante Streichung der so genannten „Generalklausel“ des $ 238 Absatz 1 Nummer 5 StGB hält der bff allerdings für äußerst problematisch. Die Erfahrung in der Unterstützung von Stalking-Betroffenen zeigt, dass die Bandbreite der nachstellenden Verhaltensweisen enorm sein kann. Gerade weil Täter und Opfer sich in der Regel kennen, denn nicht selten tritt Stalking im Rahmen von Trennungen auf, wissen Täter häufig, welche Handlungen von den Betroffenen als besonders ängstigend erlebt werden.
# In der Praxis kommen durchaus Tathandlungen vor, die durch Streichung der Generalklausel nicht mehr erfasst wären. So kommen insbesondere Sachbeschädigungen, wie z.B. das Zerstechen. von Auto- oder Fahrradreifen, Beschmieren von Wänden, Zerstörungen von Briefkästen häufiger vor. Immer wieder werden auch tote Kleintiere oder Fäkalien vor Wohnungstüren abgelegt oder auf Fahrzeugen platziert. Weiterhin ist zu bedenken, dass aufgrund der Weiterentwicklung der Digitalisierung von Kommunikation sich die Möglichkeiten der Nachstellung stetig weiter entwickeln.
#
# Die Generalklausel ist nach Ansicht des bff wichtig, damit auch Verhaltensweisen, die klar im Kontext der Nachstellungen stehen, aber von keiner der aufgezählten Begehungsvarianten erfasst werden, strafbar sind.
# Die im Gesetzentwurf beschriebene Sorge der zu weit gehenden Strafbarkeit teilt der bff nicht. Denn auch in Bezug auf den Absatz 5 wäre Voraussetzung für eine Strafbarkeit, dass die Nachstellungen „beharrlich“ und „unbefugt” vorgenommen werden müssen und dass eine Eignung zur schwerwiegenden Beeinträchtigung der Lebensführung bestehen muss. Dies ist als Eingrenzung ausreichend.
#
# Artikel 2: Änderung der Strafprozessordnung
# Die Streichung von § 238 Absatz 1 StGB aus dem Katalog der Privatklagedelikte ist uneingeschränkt zu begrüßen.
#
# Artikel 3 und 4: Ausdehnung des Tatbestandes des § 4 GewSchG
# In der Praxis zeigt sich häufig das Problem Abschlusses von bislang nicht strafbewehrten Vergleichen.
# Fachberatungsstellen haben nicht selten mit Fällen zu tun, in denen die Betroffenen davon berichten, in Verfahren nach dem Gewaltschutzgesetz im Familiengericht massiv zur Eingehung eines Vergleichs gedrängt worden zu sein. Meist haben sie in Unkenntnis der Straflosigkeit des Verstoßes gegen einen Vergleich dem Druck nachgegeben und sind erschüttert, wenn ihnen bewusst wird, dass damit der strafrechtliche Schutz entfällt.
# Wir kennen aus der Praxis den großen Erledigungsdruck der Gerichte, für die der Abschluss eines Vergleiches häufig ein einfacherer Verfahrensabschluss darstellt, als eine ggf. langwierige Beweisaufnahme. Insofern begrüßen wir es sehr, wenn nunmehr auch der Vergleich in $ 4 Abs. Nr. 2 GewaltschG aufgenommen wird. Insoweit sollte aber nicht die ,
# n i
# gerichtliche Bestätigung, wie im § 214a FamFG vorgesehen, Voraussetzung sein. Hierdurch |. würde nämlich über den Verweis auf $ 1 des GewaltschG wiederum eine umfassende prüfungspflicht, ggf. mit Beweisaufnahme durch das Gericht, erforderlich. Den ‚Gerichten
#
# gleich.
# Sinn und
# Zweck des Vergleichs ist es aber gerade nicht zuletzt auch, ‘ohne vollständige Ausermittlung des Falles eine gütliche Regelung zwischen den Parteien zu finden.
# Es stellt auch keine unzulässige Strafbarkeitsausdehnung dar, wenn nicht erst ein Gericht den Vergleich genehmigt, denn jeder Partei ist es unbenommen, einen Vergleich einzugehen oder nicht.
# Insofern halten wir eine Regelung für sinnvoll, die einen qualifizierten Vergleich für die Fälle des $ 4 GewaltSchG vorsieht. Es sollte eine gerichtliche Belehrungspflicht hinsichtlich der Strafbarkeit eines Verstoßes gegen den Vergleich erforderlich sein, die ausdrücklich im gerichtlichen Protokoll aufzunehmen ist, um die Strafbarkeit des Verstoßes gegen den Vergleich zu begründen. Es sollte außerdem als notwendiger Teil des Vergleichs Weitere Anmerkungen zum Gesetzentwurf
# Die Intention des Gesetzentwurfs, einen besseren Opferschutz in Fällen von Nachstellungen zu erreichen, ist uneingeschränkt zu begrüßen. In der Praxis der Unterstützung von Stalking-Betroffenen zeigen sich gemäß den Erfahrungen der Fachberatungsstellen weitere Schwierigkeiten, die mit dem Ziel der Verbesserung des Opferschutzes dringend bearbeitet werden sollten:
#
# aufgenommen werden, dass sich die Vergleichsparteien darüber einig sind, dass der Verstoß gegen den Vergleich eine Strafbarkeit nach 8 4 GewaitschG begründet.
#
# Die allgemein sehr lange Dauer von Ermittiungs- und Strafverfahren wirkt sich im Falle von Nachstellungen besonders negativ für die Betroffenen aus. Die nachstellenden Handlungen dauern häufig auch nach der Anzeigeerstattung fort. Die Zeitspanne bis zu einer ersten — für Betroffene, Umfeld und Täter erkennbaren — Auswirkung der Anzeigeerstattung gestaltet sich für die Betroffenen unter der stetigen Weiterwirkung oder gar Verstärkung der Nachstellungen unerträglich. Für die Beschuldigten kann die lange Dauer der staatlichen Nicht-Reaktion als Ermutigung zum Fortführen der Nachstellungen betrachtet werden. Der bff plädiert deshalb dafür, dass in Fällen von noch andauernden Nachstellungen die Möglichkeit einer Verfahrensbeschleunigung geschaffen wird.
#
# Fachberatungsstellen haben immer wieder mit Fällen zu tun, in denen ein Stalker angeklagt wird, die strafbaren nachstellenden Handlungen nachgewiesen werden können, einer Verurteilung aber die Schuldunfähigkeit des Angeklagten im Wege steht. Weil Stalking im Bereich der niedrigen Kriminalität angesiedelt ist, ist eine — in solchen Fällen eigentlich gebotene — Einweisung in eine Psychiatrie nicht möglich. Sofort nach Beendigung des Verfahrens ohne jegliche Sanktionierung wird das Stalking dann in der Regel fortgeführt oder sogar intensiviert. Den Betroffenen verbleibt keine weitere Möglichkeit mehr, den Stalker sanktioniert zu wissen. Der bff bittet nachdrücklich um die Prüfung von Lösungsmöglichkeiten für diese Fallkonstellationen im Sinne des Opferschutzes.
#
# Leider geht der Gesetzentwurf nicht auf das in der Praxis besonders relevante Problem des Stalkings ein, wenn gemeinsame Kinder und Umgangsrechte berührt sind. Hier sollte der Gesetzgeber dringend über entsprechende Regelungen nachdenken, die verhindern, dass der Gewaltschutz durch Umgangsregelungen konterkariert wird.
#
# Berlin, 04.05.2016
#
# bff: Bundesverband Frauenberatungsstellen und Frauennotrufe
# www .frauen-gegen-gewalt.de
#
# * Kamphuis, Jan H. ; Emmeikamp, Paul M. G.. (2001). Traumatic Distress Among Support-Seeking Female Victims of Stalking. American Journal of Psychiatry 2001; 158: 795-798
