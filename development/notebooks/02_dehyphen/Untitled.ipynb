# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import ddd

from pathlib import Path

# %%
Path.cwd()
# Out:
# PosixPath('/Users/user/code/ddd/experiments')

# %%
e = ddd.Export(Path('00_goofing_around/out/00001_112018_FU_Berlin_Richtlinie_2017_1371/data.json'), remove_hyphens=True)
# Out:
# Counter({4: 4460, 9: 658, 6: 99, 3: 54, 8: 43, 2: 31, 5: 28, 7: 20, 1: 13, 10: 1})
# [['Freie', 'Universität', 'Berlin,', 'Fachbereich', 'Rechtswissenschaft, '], ['Prof.', 'Dr.', 'Carsten', 'Momsen,', 'Van’t-Hoff-Str.', '8,', '14195', 'Berlin']]
# [['Fachbereich', 'Rechtswissenschaft']]
# [['Prof.', 'Dr.', 'Carsten', 'Momsen '], ['Van’t-Hoff-Str.', '8\n'], ['14195', 'Berlin']]
# [['Telefon', '+49', '(0)30', '838-59408\n'], ['+49', '(0)30', '838-58707\n'], ['Fax', '+49', '(0)30', '838-458707\n'], ['E-Mail', 'carsten.momsen@fu-berlin.de '], ['Internet', 'www.jura.fu-berlin.de '], ['Gebäude', 'Boltzmannstr.', '3,', 'Raum', '5502 '], ['14195', 'Berlin']]
# [['Bearb.-Zeichen\n'], ['Bearbeiter', 'Frau', 'Korth-Ndiaye']]
# [['Berlin,', '20.', 'November2018']]
# [['zum', 'Referentenentwurf', '(RefE)', 'des', 'Bundesministeriums', 'der', 'Justiz', 'und', 'für', 'Verbrau- '], ['cherschutz-']]
# [24.16179941879087, 25.042972479332136, 4.189229158385064]
# ...

# %%
e.to_text()
# Out:
# "Freie Universität Berlin, Fachbereich Rechtswissenschaft, Prof. Dr. Carsten Momsen, Van’t-Hoff-Str. 8, 14195 Berlin\n\nStellungnahme\n\nFachbereich Rechtswissenschaft\n\nProf. Dr. Carsten Momsen Van’t-Hoff-Str. 8\n14195 Berlin\n\nTelefon +49 (0)30 838-59408\n+49 (0)30 838-58707\nFax +49 (0)30 838-458707\nE-Mail carsten.momsen@fu-berlin.de Internet www.jura.fu-berlin.de Gebäude Boltzmannstr. 3, Raum 5502 14195 Berlin\n\nBearb.-Zeichen\nBearbeiter Frau Korth-Ndiaye\n\nBerlin, 20. November2018\n\nzum Referentenentwurf (RefE) des Bundesministeriums der Justiz und für Verbraucherschutz-\n\nEntwurf eines Gesetzes zurUmsetzung der Richtlinie (EU) 2017/1371\n\ndes Europäischen Parlaments und des Rates vom 5. Juli 2017\n\nüber die strafrechtliche Bekämpfung von gegen die finanziellen Interessen derUniongerichtetem Betrug\n\nI. Vorbemerkung ............................................................................................ 2 II. Zunehmende Kompetenzen der EU in Strafsachen? .........
# ...

# %%
def run_test(cleaner_config):
    p = doa_p
    print(p.name)
    output = ddd.run_parsr(
        str(p),
        cleaner_config=cleaner_config,
    )

    
#     texts = [x for x in e.to_text().split('\n\n') if len(x) > 0]
    return ddd.score_perplexity(e.to_text())
